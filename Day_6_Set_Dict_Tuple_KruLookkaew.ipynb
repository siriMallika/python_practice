# %% [markdown]
# <a href="https://colab.research.google.com/github/siriMallika/python_practice/blob/main/Day_6_Set_Dict_Tuple_KruLookkaew.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Exam Q3 Set/Dict/Tuple (10%)
# ## Language Model
# [Youtube Link](https://youtu.be/y4ST8vS8PpA) to help you understand this problem easier.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution

# %%
#input: a list of sentences

# %%
<s> l am Sam </s> //n
<s> Sam l am  </s> //n
<s> l am not Sam </s>

# %%
sent=[str(e) for e in input().split('//n')]
# Out:
# <s> l am Sam </s> //n <s> Sam l am  </s> //n <s> l am not Sam </s>

# %%
sent
# Out:
# ['<s> l am Sam </s> ', ' <s> Sam l am  </s> ', ' <s> l am not Sam </s>']

# %%
<s> l am Sam </s>
<s> Sam l am  </s>
<s> l am not Sam </s>

# %%
sent=[str(e) for e in input().split('</s>')]
# Out:
# <s> l am Sam </s> <s> Sam l am  </s> <s> l am not Sam </s>

# %%
sent
# Out:
# ['<s> l am Sam ', ' <s> Sam l am  ', ' <s> l am not Sam ', '']

# %% [markdown]
# # Solution#1

# %%
sent=[str(e) for e in input().split()]
# Out:
# <s> l am Sam </s> <s> Sam l am  </s> <s> l am not Sam </s>

# %%
sent
# Out:
# ['<s>',
#  'l',
#  'am',
#  'Sam',
#  '</s>',
#  '<s>',
#  'Sam',
#  'l',
#  'am',
#  '</s>',
#  '<s>',
#  'l',
#  'am',
#  'not',
#  'Sam',
#  '</s>']

# %%
sent.count('l')
# Out:
# 3

# %% [markdown]
# ## Dict : Unigram

# %% [markdown]
# # 1. Data Type
# ## 1.1 float
# ## 1.2 int
# ## 1.3 boolean --> True, False

# %% [markdown]
# # 3. Operator (ตัวดำเนินการ)
# ## 3.0 ทำในวงเล็บก่อน
# ## 3.1 ลำดับการทำงาน */ // % + - ทำจาก ซ้าย ไป ขวา
# ## 3.2 ** ยกกำลัง ทำจาก ขวา ไปซ้าย

# %% [markdown]
# # 3. รับข้อมูล และ แสดงผลบนจอ
# ## 3.1 input() --> return <String> --> input("Enter name: ")
# ## 3.2 print()

# %%
number= input("Enter number : ")
# Out:
# Enter number : 12222222

# %%
number= int(input("Enter number : "))
# Out:
# Enter number : 151515

# %%
a,b,c=[e for e in input().split()]  # รับค่าสตริงที่ เว้นว่าง 1 ช่อง 3 ตัว
# Out:
# 1 2 3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b,c=[float(e) for e in input().split()]  # รับค่าจำนวนจริงที่ เว้นว่าง 1 ช่อง 3 ตัว
# Out:
# 1.0 2.0 3.0

# %%
#1.0+2.0+3.0=6.0
print(str(a) +'+'+str(b)+'+'+str(c)+'='+str(a+b+c))
# Out:
# 1.0+2.0+3.0=6.0

# %%
number= input().strip()
# Out:
#     2kjjmkl    6

# %%
number
# Out:
# '2kjjmkl    6'

# %% [markdown]
# # 2. List && String
